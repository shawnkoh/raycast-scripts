# %%
# %autoreload 2

from smart_bear.portfolio import stuff
import uvloop
# import matplotlib.pyplot as plt
# %matplotlib inline

loop = uvloop.new_event_loop()
await stuff.main(loop)
# Out:
# 'Binance: 2582.51'
# 'RNDR/USDT:USDT'
# '\nRNDR/USDT:USDT\nAlpha: 0.0\nBeta: 1.9548182403941499\n'
# 'BTC/USDT:USDT'
# '\nBTC/USDT:USDT\nAlpha: 0.0\nBeta: 0.8846333676606981\n'
# 'WAVES/USDT:USDT'
# '\nWAVES/USDT:USDT\nAlpha: 0.0\nBeta: 1.4251203181978924\n'
